# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from keras import layers, models, utils, preprocessing


# Load and preprocess the data
with open("categorical_data.json", "r") as file:
    data = json.load(file)

# Tokenize item names
tokenizer = preprocessing.text.Tokenizer(filters='')
texts = [item["c1"] for item in data]
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

# %%
max_len = max(len(seq) for seq in sequences)

padded_sequences = utils.pad_sequences(sequences, maxlen=max_len, padding="post")

# Convert category labels to numerical form
labels = [item["c0"] for item in data]
label_map = {label: i for i, label in enumerate(set(labels))}

# %%
print(labels)
print(label_map)
# Out:
# ['PM', 'CM', 'Tool', 'CM', 'PM', 'Tool', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'CM', 'CM', 'CM', 'PM', 'PM', 'PM', 'CM', 'Tool', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'CM', 'CM', 'PM', 'Tool', 'PM', 'CM', 'CM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'Tool', 'Tool', 'CM', 'PM', 'PM', 'Tool', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'PM', 'CM', 'CM', 'PM', 'PM', 'PM', 'PM', 'CM', 'Tool', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'PM', 'CM', 'PM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'Tool', 'Tool', 'Tool', 'CM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'CM', 'PM', 'PM', 'PM', 'PM', 'CM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'PM', 'PM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'CM', 'PM', 'PM', 'CM', 'CM', 'Tool', 'Tool', 'CM', 'PM', 'CM', 'PM', 'CM', 'CM', 'PM', 'PM', 'PM', 'CM', 'CM', 'Tool', 'CM', 'CM', 'CM', 'PM', 'PM', 'CM', 'CM', 'PM', 'Tool', 'Tool', 'PM', 'PM', 'CM', 'CM', 'Tool', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'PM', 'PM', 'PM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'PM', 'CM', 'CM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'CM', 'CM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'PM', 'CM', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'PM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'PM', 'PM', 'PM', 'PM', 'CM', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'CM', 'Tool', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'PM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'CM', 'PM', 'CM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'PM', 'PM', 'CM', 'CM', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'Tool', 'PM', 'CM', 'CM', 'CM', 'Tool', 'PM', 'PM', 'Tool', 'Tool', 'CM', 'CM', 'Tool', 'PM', 'PM', 'PM', 'PM', 'Tool', 'Tool', 'Tool', 'PM', 'PM ...
# {'Tool': 0, 'CM': 1, 'PM': 2}

# %%
for (index, label) in label_map.items():
    print(index,label)
# Out:
# Tool 0
# CM 1
# PM 2

# %%
numerical_labels = np.array([label_map[label] for label in labels])
numerical_labels
# Out:
# array([2, 1, 0, ..., 0, 0, 0])

# %%
# Split data into train and validation sets
train_texts, val_texts, train_labels, val_labels = train_test_split(padded_sequences, numerical_labels, test_size=0.3, random_state=32)

# %%
len(padded_sequences)
# Out:
# 14729

# %%
# Define the TensorFlow model
model = models.Sequential(
    [
        layers.Embedding(
            input_dim=len(padded_sequences), output_dim=32, input_length=max_len
        ),
        layers.GlobalAveragePooling1D(),
        layers.Dense(32, activation="relu"),
        layers.Dropout(0.3),
        layers.Dense(16, activation="relu"),
        layers.Dropout(0.5),
        layers.Dense(len(label_map), activation="softmax"),
    ]
)

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 32, 32)            471328
#
#  global_average_pooling1d_4   (None, 32)               0
#  (GlobalAveragePooling1D)
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_17 (Dense)            (None, 16)                528
#
#  dropout_10 (Dropout)        (None, 16)                0
#
#  dense_18 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 472,963
# Trainable params: 472,963
# Non-trainable params: 0
# _________________________________________________________________

# %%
# print(train_texts.shape)
print(train_labels.shape)
print(train_texts.shape)
# Out:
# (10310,)
# (10310, 32)

# %%
train_labels.shape
# Out:
# (10310,)

# %%
history = model.fit(train_texts, train_labels, epochs=50, batch_size=3, validation_data=(val_texts, val_labels))

# Save the trained model
model.save("model_tensor_output")
# Out:
# Epoch 1/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.7487 - accuracy: 0.6480 - val_loss: 0.4801 - val_accuracy: 0.8242
# Epoch 2/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.4778 - accuracy: 0.8220 - val_loss: 0.4344 - val_accuracy: 0.8377
# Epoch 3/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.4202 - accuracy: 0.8494 - val_loss: 0.4355 - val_accuracy: 0.8298
# Epoch 4/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.3898 - accuracy: 0.8645 - val_loss: 0.4419 - val_accuracy: 0.8445
# Epoch 5/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.3476 - accuracy: 0.8769 - val_loss: 0.4318 - val_accuracy: 0.8450
# Epoch 6/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.3365 - accuracy: 0.8820 - val_loss: 0.4661 - val_accuracy: 0.8445
# Epoch 7/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.3124 - accuracy: 0.8884 - val_loss: 0.4815 - val_accuracy: 0.8461
# Epoch 8/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.3014 - accuracy: 0.8891 - val_loss: 0.5194 - val_accuracy: 0.8432
# Epoch 9/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2975 - accuracy: 0.8940 - val_loss: 0.5332 - val_accuracy: 0.8423
# Epoch 10/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2833 - accuracy: 0.8944 - val_loss: 0.5552 - val_accuracy: 0.8445
# Epoch 11/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2789 - accuracy: 0.8985 - val_loss: 0.5969 - val_accuracy: 0.8276
# Epoch 12/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2687 - accuracy: 0.9009 - val_loss: 0.5970 - val_accuracy: 0.8325
# Epoch 13/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2632 - accuracy: 0.9027 - val_loss: 0.5857 - val_accuracy: 0.8418
# Epoch 14/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2559 - accuracy: 0.8990 - val_loss: 0.6776 - val_accuracy: 0.8418
# Epoch 15/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2537 - accuracy: 0.9042 - val_loss: 0.7020 - val_accuracy: 0.8368
# Epoch 16/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2536 - accuracy: 0.9055 - val_loss: 0.7275 - val_accuracy: 0.8427
# Epoch 17/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2469 - accuracy: 0.9034 - val_loss: 0.7262 - val_accuracy: 0.8409
# Epoch 18/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2505 - accuracy: 0.9038 - val_loss: 0.7250 - val_accuracy: 0.8425
# Epoch 19/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2386 - accuracy: 0.9044 - val_loss: 0.7650 - val_accuracy: 0.8289
# Epoch 20/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2330 - accuracy: 0.9068 - val_loss: 0.7586 - val_accuracy: 0.8373
# Epoch 21/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2443 - accuracy: 0.9071 - val_loss: 0.8186 - val_accuracy: 0.8398
# Epoch 22/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2322 - accuracy: 0.9079 - val_loss: 0.8145 - val_accuracy: 0.8430
# Epoch 23/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2300 - accuracy: 0.9104 - val_loss: 0.8659 - val_accuracy: 0.8432
# Epoch 24/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2234 - accuracy: 0.9093 - val_loss: 0.9282 - val_accuracy: 0.8366
# Epoch 25/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2284 - accuracy: 0.9084 - val_loss: 0.8773 - val_accuracy: 0.8411
# Epoch 26/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2323 - accuracy: 0.9103 - val_loss: 0.8946 - val_accuracy: 0.8362
# Epoch 27/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2202 - accuracy: 0.9120 - val_loss: 1.0323 - val_accuracy: 0.8411
# Epoch 28/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2244 - accuracy: 0.9088 - val_loss: 0.9135 - val_accuracy: 0.8359
# Epoch 29/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2228 - accuracy: 0.9122 - val_loss: 1.0333 - val_accuracy: 0.8405
# Epoch 30/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2218 - accuracy: 0.9076 - val_loss: 0.9686 - val_accuracy: 0.8391
# Epoch 31/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2178 - accuracy: 0.9132 - val_loss: 0.9594 - val_accuracy: 0.8346
# Epoch 32/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2122 - accuracy: 0.9134 - val_loss: 0.9985 - val_accuracy: 0.8332
# Epoch 33/50
# 3437/3437 [==============================] - 10s 3ms/step - loss: 0.2135 - accuracy: 0.9127 - val_loss: 0.9616 - val_accuracy: 0.8393
# Epoch 34/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2118 - accuracy: 0.9130 - val_loss: 1.1236 - val_accuracy: 0.8355
# Epoch 35/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2213 - accuracy: 0.9154 - val_loss: 1.0376 - val_accuracy: 0.8371
# Epoch 36/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2120 - accuracy: 0.9117 - val_loss: 1.1164 - val_accuracy: 0.8418
# Epoch 37/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2113 - accuracy: 0.9122 - val_loss: 1.0446 - val_accuracy: 0.8350
# Epoch 38/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2109 - accuracy: 0.9107 - val_loss: 1.1667 - val_accuracy: 0.8368
# Epoch 39/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2168 - accuracy: 0.9118 - val_loss: 1.2194 - val_accuracy: 0.8366
# Epoch 40/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2099 - accuracy: 0.9136 - val_loss: 1.1147 - val_accuracy: 0.8350
# Epoch 41/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2057 - accuracy: 0.9185 - val_loss: 1.2525 - val_accuracy: 0.8407
# Epoch 42/50
# 3437/3437 [==============================] - 10s 3ms/step - loss: 0.2006 - accuracy: 0.9175 - val_loss: 1.2693 - val_accuracy: 0.8366
# Epoch 43/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2113 - accuracy: 0.9148 - val_loss: 1.2364 - val_accuracy: 0.8334
# Epoch 44/50
# 3437/3437 [==============================] - 10s 3ms/step - loss: 0.2076 - accuracy: 0.9139 - val_loss: 1.3216 - val_accuracy: 0.8391
# Epoch 45/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2108 - accuracy: 0.9145 - val_loss: 1.3616 - val_accuracy: 0.8244
# Epoch 46/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2062 - accuracy: 0.9145 - val_loss: 1.3191 - val_accuracy: 0.8387
# Epoch 47/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2039 - accuracy: 0.9153 - val_loss: 1.3133 - val_accuracy: 0.8334
# Epoch 48/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2058 - accuracy: 0.9162 - val_loss: 1.4327 - val_accuracy: 0.8400
# Epoch 49/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.1978 - accuracy: 0.9177 - val_loss: 1.3912 - val_accuracy: 0.8346
# Epoch 50/50
# 3437/3437 [==============================] - 9s 3ms/step - loss: 0.2029 - accuracy: 0.9187 - val_loss: 1.3462 - val_accuracy: 0.8393
# 2024-05-06 23:25:20.024111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2024-05-06 23:25:20.030805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# 2024-05-06 23:25:20.116219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,32]
# 	 [[{{node inputs}}]]
# 2024-05-06 23:25:20.132221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,16]
# 	 [[{{node inputs}}]]
# INFO:tensorflow:Assets written to: model_tensor_output/assets

# %%
newData = ["4x4x16 #2 yellow pin"]
# Tokenize item names
tokenizer_p = preprocessing.text.Tokenizer(filters='')
texts_p = [item for item in newData]
tokenizer_p.fit_on_texts(texts_p)
sequences_p = tokenizer_p.texts_to_sequences(texts_p)
padded_sequences_p = utils.pad_sequences(sequences_p, maxlen=max_len, padding="post")

padded_sequences_p.shape

# padded_sequences_p = utils.pad_sequences(sequences_p, maxlen=max_len, padding="post")

predictions = model.predict(padded_sequences_p)

print(predictions)

# For each prediction, you can find the index of the class with the highest probability
# predicted_labels = [np.argmax(pred) for pred in predictions]

# Then you can use this index to look up the actual label in your label map
# actual_labels = [label_map[i] for i in predicted_labels]
# print(predicted_labels)
# print(actual_labels)
# Out:
# 1/1 [==============================] - 0s 39ms/step
# [[1.1363174e-13 1.9908803e-04 9.9980098e-01]]
